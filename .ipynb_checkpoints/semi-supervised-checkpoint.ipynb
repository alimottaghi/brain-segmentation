# %% [markdown]
# # Brain MRI Segmentation
#
# This notebook contains a simplistic code for barin MRI segmentation task.
# [The dataset](https://www.kaggle.com/mateuszbuda/lgg-mri-segmentation) that is used here contains only 110 patients and is obtained from The Cancer Genome Atlas (TCGA).
# Also, some parts of this code are building on top of [this notebook](https://www.kaggle.com/mateuszbuda/brain-segmentation-pytorch).

# %%
import os
import logging
import numpy as np
import imgaug.augmenters as iaa
from tqdm import tqdm
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.transforms import Compose

from datasets.brain_dataset import BrainSegmentationDataset
from datasets.transforms import Augmentation, ToTensor, ToImage
from models.unet import UNet
from metrics.dice_loss import DiceLoss, dice_score
from train import train_supervised, train_eval_supervised, train_semi_supervised, train_eval_semi_supervised
from evaluate import evaluate, generate_outputs
from utils.params import Params, save_dict_to_json
from utils.logger import set_logger, save_checkpoint, load_checkpoint
from utils.visualizer import save_image_mask, plot_samples

# %%
dataset_dir = "/pasteur/u/mottaghi/lgg-mri-segmentation/processed"
params_path = "experiments/base_params.json"
model_dir = "experiments/semi-supervised_run2"
restore = True
os.makedirs(model_dir, exist_ok=True)

params = Params(params_path)
params.save(os.path.join(model_dir, "params.json"))
params.model_dir = model_dir
params.restore = True
params.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
set_logger(os.path.join(model_dir, "logs.txt"))

# %%
week_aug = iaa.Sequential([
    iaa.Affine(scale=(0.95, 1.05)), 
    iaa.Affine(rotate=(-15, 15)),
    iaa.Fliplr(0.5), 
])
strong_aug = iaa.Sequential([
    iaa.Affine(scale=(0.8, 1.2)), 
    iaa.Affine(rotate=(-30, 30)),
    iaa.Fliplr(0.5), 
])
week_transforms = Compose([Augmentation(week_aug), ToTensor()])
strong_transforms = Compose([Augmentation(strong_aug), ToTensor()])
params.strong_transforms = strong_transforms
totensor = ToTensor()
toimage = ToImage()

# %% [markdown]
# ### Data

# %%
labeled_dataset = BrainSegmentationDataset(dataset_dir, subset="labeled", transform=week_transforms, params=params)
unlabeled_dataset = BrainSegmentationDataset(dataset_dir, subset="unlabeled", transform=totensor, params=params)
val_dataset = BrainSegmentationDataset(dataset_dir, subset="validation", transform=totensor, params=params)

# %%
labeled_loader = DataLoader(labeled_dataset, batch_size=params.batch_size, shuffle=True, drop_last=True)
unlabeled_loader = DataLoader(unlabeled_dataset, batch_size=params.mu*params.batch_size, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=params.batch_size, drop_last=False)

# %%
rand_idx = np.random.choice(len(labeled_dataset), 5)
samples = [toimage(labeled_dataset[idx]) for idx in rand_idx]
plot_samples(samples)

# %% [markdown]
# ### Training

# %%
model = UNet(in_channels=3, out_channels=1)
model.to(params.device)
optimizer = torch.optim.Adam(model.parameters(), lr=params.learning_rate)
loss_fn = DiceLoss()
metrics = {'dice score': dice_score}

# %%
train_eval_semi_supervised(model, optimizer, loss_fn, labeled_loader, unlabeled_loader, val_loader, metrics, params)
# Out:
# Restoring parameters from experiments/semi-supervised_run2/best.pth.tar
# Epoch 120/200
# 100%|██████████| 24/24 [00:08<00:00,  2.83it/s, loss=0.236]
# - Train metrics: dice score: 0.935 ; labeled loss: 0.118 ; unlabeled loss: 0.000
# - Eval metrics : dice score: 0.686 ; loss: 0.436
# Epoch 121/200
# 100%|██████████| 24/24 [00:08<00:00,  2.82it/s, loss=0.250]
# - Train metrics: dice score: 0.927 ; labeled loss: 0.140 ; unlabeled loss: 0.103
# - Eval metrics : dice score: 0.747 ; loss: 0.393
# Epoch 122/200
# 100%|██████████| 24/24 [00:08<00:00,  2.89it/s, loss=0.236]
# - Train metrics: dice score: 0.902 ; labeled loss: 0.131 ; unlabeled loss: 0.027
# - Eval metrics : dice score: 0.695 ; loss: 0.472
# Epoch 123/200
# 100%|██████████| 24/24 [00:08<00:00,  2.83it/s, loss=0.241]
# - Train metrics: dice score: 0.882 ; labeled loss: 0.135 ; unlabeled loss: 0.158
# - Eval metrics : dice score: 0.666 ; loss: 0.418
# Epoch 124/200
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s, loss=0.218]
# - Train metrics: dice score: 0.837 ; labeled loss: 0.275 ; unlabeled loss: 0.036
# - Eval metrics : dice score: 0.713 ; loss: 0.461
# Epoch 125/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.249]
# - Train metrics: dice score: 0.929 ; labeled loss: 0.112 ; unlabeled loss: 0.043
# - Eval metrics : dice score: 0.766 ; loss: 0.405
# Epoch 126/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.343]
# - Train metrics: dice score: 0.929 ; labeled loss: 0.095 ; unlabeled loss: 0.053
# - Eval metrics : dice score: 0.641 ; loss: 0.530
# Epoch 127/200
# 100%|██████████| 24/24 [00:08<00:00,  2.89it/s, loss=0.347]
# - Train metrics: dice score: 0.706 ; labeled loss: 0.325 ; unlabeled loss: 0.049
# - Eval metrics : dice score: 0.651 ; loss: 0.429
# Epoch 128/200
# 100%|██████████| 24/24 [00:08<00:00,  2.80it/s, loss=0.243]
# - Train metrics: dice score: 0.825 ; labeled loss: 0.260 ; unlabeled loss: 0.070
# - Eval metrics : dice score: 0.640 ; loss: 0.519
# Epoch 129/200
# 100%|██████████| 24/24 [00:08<00:00,  2.82it/s, loss=0.234]
# - Train metrics: dice score: 0.912 ; labeled loss: 0.110 ; unlabeled loss: 0.053
# - Eval metrics : dice score: 0.714 ; loss: 0.447
# Epoch 130/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.228]
# - Train metrics: dice score: 0.949 ; labeled loss: 0.076 ; unlabeled loss: 0.087
# - Eval metrics : dice score: 0.687 ; loss: 0.472
# Epoch 131/200
# 100%|██████████| 24/24 [00:08<00:00,  2.82it/s, loss=0.224]
# - Train metrics: dice score: 0.935 ; labeled loss: 0.082 ; unlabeled loss: 0.068
# - Eval metrics : dice score: 0.749 ; loss: 0.412
# Epoch 132/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.204]
# - Train metrics: dice score: 0.963 ; labeled loss: 0.055 ; unlabeled loss: 0.066
# - Eval metrics : dice score: 0.715 ; loss: 0.454
# Epoch 133/200
# 100%|██████████| 24/24 [00:08<00:00,  2.91it/s, loss=0.273]
# - Train metrics: dice score: 0.920 ; labeled loss: 0.127 ; unlabeled loss: 0.051
# - Eval metrics : dice score: 0.607 ; loss: 0.559
# Epoch 134/200
# 100%|██████████| 24/24 [00:08<00:00,  2.89it/s, loss=0.262]
# - Train metrics: dice score: 0.715 ; labeled loss: 0.321 ; unlabeled loss: 0.025
# - Eval metrics : dice score: 0.794 ; loss: 0.381
# Epoch 135/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.223]
# - Train metrics: dice score: 0.933 ; labeled loss: 0.089 ; unlabeled loss: 0.039
# - Eval metrics : dice score: 0.765 ; loss: 0.407
# Epoch 136/200
# 100%|██████████| 24/24 [00:08<00:00,  2.80it/s, loss=0.233]
# - Train metrics: dice score: 0.936 ; labeled loss: 0.094 ; unlabeled loss: 0.046
# - Eval metrics : dice score: 0.775 ; loss: 0.399
# Epoch 137/200
# 100%|██████████| 24/24 [00:08<00:00,  2.86it/s, loss=0.235]
# - Train metrics: dice score: 0.913 ; labeled loss: 0.184 ; unlabeled loss: 0.754
# - Eval metrics : dice score: 0.778 ; loss: 0.390
# Epoch 138/200
# 100%|██████████| 24/24 [00:08<00:00,  2.67it/s, loss=0.195]
# - Train metrics: dice score: 0.947 ; labeled loss: 0.148 ; unlabeled loss: 0.067
# - Eval metrics : dice score: 0.769 ; loss: 0.400
# Epoch 139/200
# 100%|██████████| 24/24 [00:08<00:00,  2.70it/s, loss=0.224]
# - Train metrics: dice score: 0.956 ; labeled loss: 0.071 ; unlabeled loss: 0.042
# - Eval metrics : dice score: 0.747 ; loss: 0.376
# Epoch 140/200
# 100%|██████████| 24/24 [00:10<00:00,  2.21it/s, loss=0.208]
# - Train metrics: dice score: 0.905 ; labeled loss: 0.128 ; unlabeled loss: 0.037
# - Eval metrics : dice score: 0.663 ; loss: 0.491
# Epoch 141/200
# 100%|██████████| 24/24 [00:10<00:00,  2.23it/s, loss=0.241]
# - Train metrics: dice score: 0.000 ; labeled loss: 0.999 ; unlabeled loss: 0.052
# - Eval metrics : dice score: 0.614 ; loss: 0.448
# Epoch 142/200
# 100%|██████████| 24/24 [00:08<00:00,  2.72it/s, loss=0.226]
# - Train metrics: dice score: 0.791 ; labeled loss: 0.264 ; unlabeled loss: 0.037
# - Eval metrics : dice score: 0.746 ; loss: 0.410
# Epoch 143/200
# 100%|██████████| 24/24 [00:08<00:00,  2.72it/s, loss=0.222]
# - Train metrics: dice score: 0.944 ; labeled loss: 0.065 ; unlabeled loss: 0.051
# - Eval metrics : dice score: 0.755 ; loss: 0.410
# Epoch 144/200
# 100%|██████████| 24/24 [00:08<00:00,  2.80it/s, loss=0.204]
# - Train metrics: dice score: 0.921 ; labeled loss: 0.118 ; unlabeled loss: 0.040
# - Eval metrics : dice score: 0.747 ; loss: 0.407
# Epoch 145/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.189]
# - Train metrics: dice score: 0.897 ; labeled loss: 0.135 ; unlabeled loss: 0.034
# - Eval metrics : dice score: 0.709 ; loss: 0.445
# Epoch 146/200
# 100%|██████████| 24/24 [00:08<00:00,  2.85it/s, loss=0.208]
# - Train metrics: dice score: 0.928 ; labeled loss: 0.089 ; unlabeled loss: 0.045
# - Eval metrics : dice score: 0.756 ; loss: 0.400
# Epoch 147/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.178]
# - Train metrics: dice score: 0.934 ; labeled loss: 0.079 ; unlabeled loss: 0.072
# - Eval metrics : dice score: 0.739 ; loss: 0.416
# Epoch 148/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.207]
# - Train metrics: dice score: 0.926 ; labeled loss: 0.103 ; unlabeled loss: 0.052
# - Eval metrics : dice score: 0.728 ; loss: 0.427
# Epoch 149/200
# 100%|██████████| 24/24 [00:08<00:00,  2.85it/s, loss=0.237]
# - Train metrics: dice score: 0.937 ; labeled loss: 0.089 ; unlabeled loss: 0.137
# - Eval metrics : dice score: 0.769 ; loss: 0.386
# Epoch 150/200
# 100%|██████████| 24/24 [00:08<00:00,  2.74it/s, loss=0.181]
# - Train metrics: dice score: 0.924 ; labeled loss: 0.097 ; unlabeled loss: 0.035
# - Eval metrics : dice score: 0.705 ; loss: 0.399
# Epoch 151/200
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s, loss=0.196]
# - Train metrics: dice score: 0.923 ; labeled loss: 0.093 ; unlabeled loss: 0.102
# - Eval metrics : dice score: 0.696 ; loss: 0.461
# Epoch 152/200
# 100%|██████████| 24/24 [00:08<00:00,  2.74it/s, loss=0.188]
# - Train metrics: dice score: 0.950 ; labeled loss: 0.059 ; unlabeled loss: 0.034
# - Eval metrics : dice score: 0.747 ; loss: 0.406
# Epoch 153/200
# 100%|██████████| 24/24 [00:08<00:00,  2.70it/s, loss=0.189]
# - Train metrics: dice score: 0.872 ; labeled loss: 0.196 ; unlabeled loss: 0.119
# - Eval metrics : dice score: 0.799 ; loss: 0.364
# Epoch 154/200
# 100%|██████████| 24/24 [00:08<00:00,  2.71it/s, loss=0.184]
# - Train metrics: dice score: 0.916 ; labeled loss: 0.106 ; unlabeled loss: 0.085
# - Eval metrics : dice score: 0.752 ; loss: 0.401
# Epoch 155/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.211]
# - Train metrics: dice score: 0.952 ; labeled loss: 0.053 ; unlabeled loss: 0.053
# - Eval metrics : dice score: 0.637 ; loss: 0.420
# Epoch 156/200
# 100%|██████████| 24/24 [00:08<00:00,  2.72it/s, loss=0.206]
# - Train metrics: dice score: 0.882 ; labeled loss: 0.162 ; unlabeled loss: 0.054
# - Eval metrics : dice score: 0.753 ; loss: 0.363
# Epoch 157/200
# 100%|██████████| 24/24 [00:08<00:00,  2.69it/s, loss=0.265]
# - Train metrics: dice score: 0.946 ; labeled loss: 0.062 ; unlabeled loss: 0.305
# - Eval metrics : dice score: 0.709 ; loss: 0.409
# Epoch 158/200
# 100%|██████████| 24/24 [00:08<00:00,  2.85it/s, loss=0.229]
# - Train metrics: dice score: 0.839 ; labeled loss: 0.202 ; unlabeled loss: 0.036
# - Eval metrics : dice score: 0.745 ; loss: 0.407
# Epoch 159/200
# 100%|██████████| 24/24 [00:08<00:00,  2.86it/s, loss=0.211]
# - Train metrics: dice score: 0.944 ; labeled loss: 0.070 ; unlabeled loss: 0.029
# - Eval metrics : dice score: 0.695 ; loss: 0.458
# Epoch 160/200
# 100%|██████████| 24/24 [00:08<00:00,  2.81it/s, loss=0.194]
# - Train metrics: dice score: 0.895 ; labeled loss: 0.150 ; unlabeled loss: 0.098
# - Eval metrics : dice score: 0.689 ; loss: 0.461
# Epoch 161/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.189]
# - Train metrics: dice score: 0.915 ; labeled loss: 0.103 ; unlabeled loss: 0.066
# - Eval metrics : dice score: 0.781 ; loss: 0.377
# Epoch 162/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.182]
# - Train metrics: dice score: 0.953 ; labeled loss: 0.060 ; unlabeled loss: 0.020
# - Eval metrics : dice score: 0.725 ; loss: 0.426
# Epoch 163/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.185]
# - Train metrics: dice score: 0.880 ; labeled loss: 0.149 ; unlabeled loss: 0.067
# - Eval metrics : dice score: 0.722 ; loss: 0.428
# Epoch 164/200
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s, loss=0.200]
# - Train metrics: dice score: 0.921 ; labeled loss: 0.090 ; unlabeled loss: 0.050
# - Eval metrics : dice score: 0.666 ; loss: 0.438
# Epoch 165/200
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s, loss=0.199]
# - Train metrics: dice score: 0.948 ; labeled loss: 0.064 ; unlabeled loss: 0.047
# - Eval metrics : dice score: 0.766 ; loss: 0.384
# Epoch 166/200
# 100%|██████████| 24/24 [00:08<00:00,  2.71it/s, loss=0.351]
# - Train metrics: dice score: 0.923 ; labeled loss: 0.090 ; unlabeled loss: 0.050
# - Eval metrics : dice score: 0.500 ; loss: 0.511
# Epoch 167/200
# 100%|██████████| 24/24 [00:08<00:00,  2.82it/s, loss=0.263]
# - Train metrics: dice score: 0.471 ; labeled loss: 0.554 ; unlabeled loss: 0.293
# - Eval metrics : dice score: 0.651 ; loss: 0.411
# Epoch 168/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.191]
# - Train metrics: dice score: 0.930 ; labeled loss: 0.081 ; unlabeled loss: 0.047
# - Eval metrics : dice score: 0.670 ; loss: 0.392
# Epoch 169/200
# 100%|██████████| 24/24 [00:08<00:00,  2.81it/s, loss=0.196]
# - Train metrics: dice score: 0.900 ; labeled loss: 0.114 ; unlabeled loss: 0.000
# - Eval metrics : dice score: 0.687 ; loss: 0.424
# Epoch 170/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.169]
# - Train metrics: dice score: 0.868 ; labeled loss: 0.166 ; unlabeled loss: 0.057
# - Eval metrics : dice score: 0.729 ; loss: 0.379
# Epoch 171/200
# 100%|██████████| 24/24 [00:08<00:00,  2.79it/s, loss=0.233]
# - Train metrics: dice score: 0.939 ; labeled loss: 0.094 ; unlabeled loss: 0.090
# - Eval metrics : dice score: 0.772 ; loss: 0.340
# Epoch 172/200
# 100%|██████████| 24/24 [00:08<00:00,  2.75it/s, loss=0.211]
# - Train metrics: dice score: 0.662 ; labeled loss: 0.394 ; unlabeled loss: 0.087
# - Eval metrics : dice score: 0.740 ; loss: 0.370
# Epoch 173/200
# 100%|██████████| 24/24 [00:08<00:00,  2.83it/s, loss=0.248]
# - Train metrics: dice score: 0.874 ; labeled loss: 0.151 ; unlabeled loss: 0.033
# - Eval metrics : dice score: 0.697 ; loss: 0.364
# Epoch 174/200
# 100%|██████████| 24/24 [00:08<00:00,  2.69it/s, loss=0.184]
# - Train metrics: dice score: 0.910 ; labeled loss: 0.101 ; unlabeled loss: 0.099
# - Eval metrics : dice score: 0.703 ; loss: 0.404
# Epoch 175/200
# 100%|██████████| 24/24 [00:08<00:00,  2.75it/s, loss=0.155]
# - Train metrics: dice score: 0.934 ; labeled loss: 0.070 ; unlabeled loss: 0.072
# - Eval metrics : dice score: 0.680 ; loss: 0.381
# Epoch 176/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.161]
# - Train metrics: dice score: 0.931 ; labeled loss: 0.088 ; unlabeled loss: 0.027
# - Eval metrics : dice score: 0.704 ; loss: 0.357
# Epoch 177/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.196]
# - Train metrics: dice score: 0.931 ; labeled loss: 0.086 ; unlabeled loss: 0.026
# - Eval metrics : dice score: 0.711 ; loss: 0.395
# Epoch 178/200
# 100%|██████████| 24/24 [00:08<00:00,  2.74it/s, loss=0.163]
# - Train metrics: dice score: 0.839 ; labeled loss: 0.201 ; unlabeled loss: 0.055
# - Eval metrics : dice score: 0.698 ; loss: 0.409
# Epoch 179/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.163]
# - Train metrics: dice score: 0.906 ; labeled loss: 0.126 ; unlabeled loss: 0.031
# - Eval metrics : dice score: 0.751 ; loss: 0.402
# Epoch 180/200
# 100%|██████████| 24/24 [00:09<00:00,  2.64it/s, loss=0.165]
# - Train metrics: dice score: 0.924 ; labeled loss: 0.091 ; unlabeled loss: 0.024
# - Eval metrics : dice score: 0.647 ; loss: 0.410
# Epoch 181/200
# 100%|██████████| 24/24 [00:08<00:00,  2.71it/s, loss=0.175]
# - Train metrics: dice score: 0.931 ; labeled loss: 0.081 ; unlabeled loss: 0.084
# - Eval metrics : dice score: 0.644 ; loss: 0.413
# Epoch 182/200
# 100%|██████████| 24/24 [00:08<00:00,  2.74it/s, loss=0.212]
# - Train metrics: dice score: 0.970 ; labeled loss: 0.034 ; unlabeled loss: 0.073
# - Eval metrics : dice score: 0.708 ; loss: 0.398
# Epoch 183/200
# 100%|██████████| 24/24 [00:08<00:00,  2.71it/s, loss=0.175]
# - Train metrics: dice score: 0.956 ; labeled loss: 0.066 ; unlabeled loss: 0.101
# - Eval metrics : dice score: 0.742 ; loss: 0.412
# Epoch 184/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.175]
# - Train metrics: dice score: 0.950 ; labeled loss: 0.062 ; unlabeled loss: 0.037
# - Eval metrics : dice score: 0.742 ; loss: 0.410
# Epoch 185/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.224]
# - Train metrics: dice score: 0.923 ; labeled loss: 0.084 ; unlabeled loss: 0.037
# - Eval metrics : dice score: 0.789 ; loss: 0.364
# Epoch 186/200
# 100%|██████████| 24/24 [00:08<00:00,  2.70it/s, loss=0.200]
# - Train metrics: dice score: 0.953 ; labeled loss: 0.076 ; unlabeled loss: 0.029
# - Eval metrics : dice score: 0.712 ; loss: 0.393
# Epoch 187/200
# 100%|██████████| 24/24 [00:08<00:00,  2.77it/s, loss=0.166]
# - Train metrics: dice score: 0.944 ; labeled loss: 0.104 ; unlabeled loss: 0.100
# - Eval metrics : dice score: 0.751 ; loss: 0.402
# Epoch 188/200
# 100%|██████████| 24/24 [00:08<00:00,  2.75it/s, loss=0.184]
# - Train metrics: dice score: 0.927 ; labeled loss: 0.083 ; unlabeled loss: 0.100
# - Eval metrics : dice score: 0.689 ; loss: 0.369
# Epoch 189/200
# 100%|██████████| 24/24 [00:08<00:00,  2.68it/s, loss=0.171]
# - Train metrics: dice score: 0.926 ; labeled loss: 0.087 ; unlabeled loss: 0.036
# - Eval metrics : dice score: 0.719 ; loss: 0.427
# Epoch 190/200
# 100%|██████████| 24/24 [00:08<00:00,  2.75it/s, loss=0.222]
# - Train metrics: dice score: 0.901 ; labeled loss: 0.106 ; unlabeled loss: 0.062
# - Eval metrics : dice score: 0.753 ; loss: 0.351
# Epoch 191/200
# 100%|██████████| 24/24 [00:08<00:00,  2.78it/s, loss=0.212]
# - Train metrics: dice score: 0.901 ; labeled loss: 0.106 ; unlabeled loss: 0.037
# - Eval metrics : dice score: 0.724 ; loss: 0.334
# Epoch 192/200
# 100%|██████████| 24/24 [00:08<00:00,  2.71it/s, loss=0.194]
# - Train metrics: dice score: 0.955 ; labeled loss: 0.060 ; unlabeled loss: 0.045
# - Eval metrics : dice score: 0.774 ; loss: 0.378
# Epoch 193/200
# 100%|██████████| 24/24 [00:08<00:00,  2.73it/s, loss=0.151]
# - Train metrics: dice score: 0.927 ; labeled loss: 0.080 ; unlabeled loss: 0.039
# - Eval metrics : dice score: 0.801 ; loss: 0.351
# Epoch 194/200
# 100%|██████████| 24/24 [00:08<00:00,  2.68it/s, loss=0.170]
# - Train metrics: dice score: 0.912 ; labeled loss: 0.102 ; unlabeled loss: 0.020
# - Eval metrics : dice score: 0.700 ; loss: 0.403
# Epoch 195/200
# 100%|██████████| 24/24 [00:08<00:00,  2.72it/s, loss=0.177]
# - Train metrics: dice score: 0.937 ; labeled loss: 0.069 ; unlabeled loss: 0.055
# - Eval metrics : dice score: 0.748 ; loss: 0.403
# Epoch 196/200
# 100%|██████████| 24/24 [00:08<00:00,  2.79it/s, loss=0.163]
# - Train metrics: dice score: 0.802 ; labeled loss: 0.244 ; unlabeled loss: 0.190
# - Eval metrics : dice score: 0.767 ; loss: 0.384
# Epoch 197/200
# 100%|██████████| 24/24 [00:08<00:00,  2.76it/s, loss=0.159]
# - Train metrics: dice score: 0.934 ; labeled loss: 0.071 ; unlabeled loss: 0.050
# - Eval metrics : dice score: 0.719 ; loss: 0.385
# Epoch 198/200
# 100%|██████████| 24/24 [00:08<00:00,  2.74it/s, loss=0.173]
# - Train metrics: dice score: 0.928 ; labeled loss: 0.086 ; unlabeled loss: 0.028
# - Eval metrics : dice score: 0.688 ; loss: 0.457
# Epoch 199/200
# 100%|██████████| 24/24 [00:08<00:00,  2.68it/s, loss=0.205]
# - Train metrics: dice score: 0.895 ; labeled loss: 0.115 ; unlabeled loss: 0.058
# - Eval metrics : dice score: 0.620 ; loss: 0.524
# Epoch 200/200
# 100%|██████████| 24/24 [00:08<00:00,  2.82it/s, loss=0.168]
# - Train metrics: dice score: 0.888 ; labeled loss: 0.167 ; unlabeled loss: 0.055
# - Eval metrics : dice score: 0.718 ; loss: 0.427

# %% [markdown]
# ### Evaluation

# %%
output_list = generate_outputs(model, val_loader, params, save=True)
# Out:
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_155.png is a low contrast image
#   imsave(path, image)
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_207.png is a low contrast image
#   imsave(path, image)
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_208.png is a low contrast image
#   imsave(path, image)
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_209.png is a low contrast image
#   imsave(path, image)
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_260.png is a low contrast image
#   imsave(path, image)
# /sailhome/mottaghi/brain-segmentation/utils/visualizer.py:33: UserWarning: experiments/semi-supervised_run2/output/val_295.png is a low contrast image
#   imsave(path, image)

# %%
rand_idx = np.random.choice(len(output_list), 5)
samples = [output_list[idx] for idx in rand_idx]
plot_samples(samples)
